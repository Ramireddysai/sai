# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Downloads/fiat500(1).csv")

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
data.tail(10)
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 1528  1529  lounge            51         2861  126000                1
# 1529  1530  lounge            51          731   22551                1
# 1530  1531  lounge            51          670   29000                1
# 1531  1532   sport            73         4505  127000                1
# 1532  1533     pop            51         1917   52008                1
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat       lon  price
# 1528  43.841980  10.51531   5500
# 1529  38.122070  13.36112   9900
# 1530  45.764648   8.99450  10800
# 1531  45.528511   9.59323   4750
# ...

# %%
data.tail(10)
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 1528  1529  lounge            51         2861  126000                1
# 1529  1530  lounge            51          731   22551                1
# 1530  1531  lounge            51          670   29000                1
# 1531  1532   sport            73         4505  127000                1
# 1532  1533     pop            51         1917   52008                1
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat       lon  price
# 1528  43.841980  10.51531   5500
# 1529  38.122070  13.36112   9900
# 1530  45.764648   8.99450  10800
# 1531  45.528511   9.59323   4750
# ...

# %%
data.head(10)
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
# 5   6     pop            74         3623   70225                1  45.000702
# 6   7  lounge            51          731   11600                1  44.907242
# 7   8  lounge            51         1521   49076                1  41.903221
# 8   9   sport            73         4049   76000                1  45.548000
# 9  10   sport            51         3653   89000                1  45.438301
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# ...

# %%
data['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport'], dtype=object)

# %%
data['price'].unique()
# Out:
# array([ 8900,  8800,  4200,  6000,  5700,  7900, 10750,  9190,  5600,
#         8950, 10990,  9700,  4800,  9300,  9500,  5250,  7990,  7300,
#        10500,  6990, 10600, 10200,  9990, 10800,  6800,  4950, 10640,
#         5900,  5200,  9790,  5000,  8990,  7200,  9950,  9000,  4890,
#        10900,  5999, 10400,  7500,  4900,  4300,  6999,  5990,  5500,
#         7450,  8250,  9800,  9900,  4490,  7400, 10700,  7800, 10050,
#         4799,  8100,  5800,  9390,  7490,  9970,  8980, 10465,  5950,
#         8500,  8790, 10000,  9400,  6100,  6500, 10650, 10950, 11000,
#         7700,  6300, 10250,  4990,  8200, 10550,  6900,  6700,  9490,
#        10279, 11090,  8000,  5400,  8700, 10280,  4500,  4250,  9450,
#         9590,  9600,  5399, 10670,  5300, 10850,  7600,  5100,  6600,
#         9435, 10300,  4390,  8390, 10470,  3390,  9980,  9850,  5490,
#         7950,  9750,  4600, 10999,  9100,  6200,  8400,  8750,  8290,
# ...

# %%
list(data.columns)
# Out:
# ['ID',
#  'model',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
list(data.columns[3])
# Out:
# ['a', 'g', 'e', '_', 'i', 'n', '_', 'd', 'a', 'y', 's']

# %%
data.groupby(['previous_owners']).count()
# Out:
#                    ID  model  engine_power  age_in_days    km   lat   lon  \
# previous_owners
# 1                1389   1389          1389         1389  1389  1389  1389
# 2                 117    117           117          117   117   117   117
# 3                  23     23            23           23    23    23    23
# 4                   9      9             9            9     9     9     9
#
#                  price
# previous_owners
# 1                 1389
# 2                  117
# 3                   23
# 4                    9

# %%
data.groupby(['model']).count()
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1094          1094         1094  1094             1094  1094  1094
# pop      358           358          358   358              358   358   358
# sport     86            86           86    86               86    86    86
#
#         price
# model
# lounge   1094
# pop       358
# sport      86

# %%
data1=data.drop(['lat','ID'],axis=1)

# %%
data1=data.drop(['lat','ID'],axis=1)

# %%
data1.head()
# Out:
#     model  engine_power  age_in_days      km  previous_owners        lon  \
# 0  lounge            51          882   25000                1   8.611560
# 1     pop            51         1186   32500                1  12.241890
# 2   sport            74         4658  142228                1  11.417840
# 3  lounge            51         2739  160000                1  17.634609
# 4     pop            73         3074  106880                1  12.495650
#
#    price
# 0   8900
# 1   8800
# 2   4200
# 3   6000
# 4   5700

# %%
data['price'].sum()
# Out:
# 13189894

# %%
data2=data.loc[(data.model=='longe')]
data2
# Out:
# Empty DataFrame
# Columns: [ID, model, engine_power, age_in_days, km, previous_owners, lat, lon, price]
# Index: []

# %%
data2=data.loc[(data.model=='lounge')]
data2
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 3        4  lounge            51         2739  160000                1
# 6        7  lounge            51          731   11600                1
# 7        8  lounge            51         1521   49076                1
# 11      12  lounge            51          366   17500                1
# ...    ...     ...           ...          ...     ...              ...
# 1528  1529  lounge            51         2861  126000                1
# 1529  1530  lounge            51          731   22551                1
# 1530  1531  lounge            51          670   29000                1
# 1534  1535  lounge            74         3835  112000                1
# 1536  1537  lounge            51         2557   80750                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 3     40.633171  17.634609   6000
# ...

# %%
data2=data.loc[(data.model=='km')]
data2
# Out:
# Empty DataFrame
# Columns: [ID, model, engine_power, age_in_days, km, previous_owners, lat, lon, price]
# Index: []

# %%
data2=data.loc[(data.km<=25000)]
data2
# Out:
#         ID   model  engine_power  age_in_days     km  previous_owners  \
# 0        1  lounge            51          882  25000                1
# 6        7  lounge            51          731  11600                1
# 11      12  lounge            51          366  17500                1
# 12      13  lounge            51          456  18450                1
# 19      20  lounge            51          425  20030                1
# ...    ...     ...           ...          ...    ...              ...
# 1520  1521  lounge            51         1035  15000                1
# 1522  1523  lounge            51          366  14618                1
# 1526  1527  lounge            51         1705  23600                1
# 1527  1528     pop            51          517   3000                1
# 1529  1530  lounge            51          731  22551                1
#
#             lat       lon  price
# 0     44.907242   8.61156   8900
# 6     44.907242   8.61156  10750
# ...

# %%
data2=data.loc[(data.model=='pop')&(data.previous_owners==1)]
data2
# Out:
#         ID model  engine_power  age_in_days      km  previous_owners  \
# 1        2   pop            51         1186   32500                1
# 4        5   pop            73         3074  106880                1
# 5        6   pop            74         3623   70225                1
# 10      11   pop            51          790   43286                1
# 13      14   pop            51         3835  120000                1
# ...    ...   ...           ...          ...     ...              ...
# 1524  1525   pop            51         2192   53300                1
# 1527  1528   pop            51          517    3000                1
# 1532  1533   pop            51         1917   52008                1
# 1535  1536   pop            51         2223   60457                1
# 1537  1538   pop            51         1766   54276                1
#
#             lat        lon  price
# 1     45.666359  12.241890   8800
# 4     41.903221  12.495650   5700
# ...

# %%
data2.iloc[10]
# Out:
# ID                        42
# model                    pop
# engine_power              51
# age_in_days              609
# km                     28500
# previous_owners            1
# lat                45.746021
# lon                  9.04997
# price                  10900
# Name: 41, dtype: object

# %%
data2=data.loc[(data.model=='pop')^(data.model=='launge')]
data2
# Out:
#         ID model  engine_power  age_in_days      km  previous_owners  \
# 1        2   pop            51         1186   32500                1
# 4        5   pop            73         3074  106880                1
# 5        6   pop            74         3623   70225                1
# 10      11   pop            51          790   43286                1
# 13      14   pop            51         3835  120000                1
# ...    ...   ...           ...          ...     ...              ...
# 1524  1525   pop            51         2192   53300                1
# 1527  1528   pop            51          517    3000                1
# 1532  1533   pop            51         1917   52008                1
# 1535  1536   pop            51         2223   60457                1
# 1537  1538   pop            51         1766   54276                1
#
#             lat        lon  price
# 1     45.666359  12.241890   8800
# 4     41.903221  12.495650   5700
# ...

# %%
data2=data.loc[(data.model=='pop')|(data.model=='launge')]
data2
data2.plot()
# Out:
# <Axes: >

# %%
data2[1:13]
# Out:
#     ID model  engine_power  age_in_days      km  previous_owners        lat  \
# 4    5   pop            73         3074  106880                1  41.903221
# 5    6   pop            74         3623   70225                1  45.000702
# 10  11   pop            51          790   43286                1  40.871429
# 13  14   pop            51         3835  120000                1  40.531590
# 17  18   pop            51         2223   96848                1  43.782372
# 26  27   pop            51         3592  124000                1  40.966179
# 35  36   pop            51         3653  138116                2  40.633171
# 36  37   pop            51          852   17000                1  45.505161
# 37  38   pop            51         3013   58527                1  45.688259
# 39  40   pop            51         1858   13373                1  41.903221
# 41  42   pop            51          609   28500                1  45.746021
# ...

# %%
import pandas as pd

# %%
data9=pd.read_csv("/home/placement/Downloads/fiat500(1).csv")

# %%
data9
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
data9['model']=data9['model'].map({'lounge':1,'pop':2,'sport':3})

# %%
data9
# Out:
#         ID  model  engine_power  age_in_days      km  previous_owners  \
# 0        1      1            51          882   25000                1
# 1        2      2            51         1186   32500                1
# 2        3      3            74         4658  142228                1
# 3        4      1            51         2739  160000                1
# 4        5      2            73         3074  106880                1
# ...    ...    ...           ...          ...     ...              ...
# 1533  1534      3            51         3712  115280                1
# 1534  1535      1            74         3835  112000                1
# 1535  1536      2            51         2223   60457                1
# 1536  1537      1            51         2557   80750                1
# 1537  1538      2            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
data9.head()
# Out:
#    ID  model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1      1            51          882   25000                1  44.907242
# 1   2      2            51         1186   32500                1  45.666359
# 2   3      3            74         4658  142228                1  45.503300
# 3   4      1            51         2739  160000                1  40.633171
# 4   5      2            73         3074  106880                1  41.903221
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# 4  12.495650   5700

# %%
cor_mat=data9.corr()
cor_mat
# Out:
#                        ID     model  engine_power  age_in_days        km  \
# ID               1.000000 -0.024740     -0.034059    -0.060753 -0.006537
# model           -0.024740  1.000000      0.189906     0.326508  0.319580
# engine_power    -0.034059  0.189906      1.000000     0.319190  0.285495
# age_in_days     -0.060753  0.326508      0.319190     1.000000  0.833890
# km              -0.006537  0.319580      0.285495     0.833890  1.000000
# previous_owners  0.007803  0.052480     -0.005030     0.075775  0.097539
# lat             -0.058207  0.044901      0.005721     0.062982  0.035519
# lon              0.058941 -0.013200     -0.005032    -0.042667  0.004839
# price            0.028516 -0.349885     -0.277235    -0.893328 -0.859373
#
#                  previous_owners       lat       lon     price
# ID                      0.007803 -0.058207  0.058941  0.028516
# model                   0.052480  0.044901 -0.013200 -0.349885
# ...

# %%
import seaborn as sns
sns.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >
